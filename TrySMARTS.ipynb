# %%
from rdkit import Chem
from rdkit.Chem.Draw import MolsToGridImage

# %%
smiles_list = ["CCCCC","CCOCC","CCNCC","CCSCC"]
mol_list = [Chem.MolFromSmiles(x) for x in smiles_list]

# %%
MolsToGridImage(mols=mol_list, molsPerRow=4)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x200 at 0x111567630>

# %%
query = Chem.MolFromSmarts("CCC")
match_list = [mol.GetSubstructMatch(query) for mol in mol_list]
MolsToGridImage(mols=mol_list, molsPerRow=4, highlightAtomLists=match_list)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x200 at 0x118974D30>

# %%
query = Chem.MolFromSmarts("C*C")
match_list = [mol.GetSubstructMatch(query) for mol in mol_list]
MolsToGridImage(mols=mol_list, molsPerRow=4, highlightAtomLists=match_list)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x200 at 0x1189749E8>

# %%
query = Chem.MolFromSmarts("C[C,N,O]C")
match_list = [mol.GetSubstructMatch(query) for mol in mol_list]
MolsToGridImage(mols=mol_list, molsPerRow=4, highlightAtomLists=match_list)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x200 at 0x118974CF8>
